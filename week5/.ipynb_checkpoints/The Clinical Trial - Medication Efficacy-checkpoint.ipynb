# %% [markdown]
# # The Clinical Trial - Medication Efficacy
# #### Dataset: Synthetic data (manually typed lists).
# #### Goal: Reinforce the Matplotlib Object-Oriented canvas structure and introduce basic Seaborn styling to track how two different medications reduce pain over time.

# %% [markdown]
# ## 1. Importing Libraries & Theming:
# #### Start by importing matplotlib.pyplot as plt and import seaborn as sns.
# #### New Skill: Before creating your plot, use Seaborn to instantly upgrade the visuals by setting a theme. Call sns.set_theme(style="darkgrid").

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid")

# %% [markdown]
# ## 2. The Anatomy / Basic Plotting:
# #### Create lists to track a 6-hour window.
# #### hours = [1, 2, 3, 4, 5, 6]
# #### Create two lists for the medications, representing reported pain levels on a scale of 0 to 10 (e.g., med_A_pain = [8, 6, 5, 3, 2, 2]).
# #### Set up your canvas using the Object-Oriented method: fig, ax = plt.subplots().
# #### Plot the data using ax.plot(hours, med_A_pain) and ax.plot(hours, med_B_pain).
# #### New Skill: Inside your ax.plot() calls, try adding markers and specific colors to differentiate the lines further (e.g., ax.plot(..., color='blue', marker='o', label='Medication A')).
# ## 3. Basic Customization:
# #### Instruct the canvas to display your metadata:
# #### ax.set_title("Pain Level Over Time: Med A vs. Med B")
# #### ax.set_xlabel("Hours Post-Dose")
# #### ax.set_ylabel("Reported Pain Level (0-10)")
# #### Call ax.legend() so the viewer knows which line represents which medication.
# #### Finally, render the plot cleanly with plt.show().

# %%
hours = [1, 2, 3, 4, 5, 6]
med_A_pain = [8, 6, 5, 3, 2, 2]
med_B_pain = [9, 8, 7, 5, 4, 3] 

fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(hours, med_A_pain, color='blue', marker='o', label='Medication A', linewidth=2)
ax.plot(hours, med_B_pain, color='orange', marker='s', label='Medication B', linewidth=2)

ax.set_title("Pain Level Over Time: Med A vs. Med B", fontsize=14, fontweight='bold')
ax.set_xlabel("Hours Post-Dose", fontsize=12)
ax.set_ylabel("Reported Pain Level (0-10)", fontsize=12)

ax.legend()

plt.show()

# %% [markdown]
# ## 4. Explain each of the graphs in details(both Khmer and English)

# %% [markdown]
# # English Explanation
# This graph visually compares the effectiveness of two different medications in reducing a patient's pain over a 6-hour period.
#
# The Axes: The X-axis tracks time, specifically the hours passed since the medication was taken (Hours Post-Dose). The Y-axis represents the severity of the pain on a scale from 0 to 10, where 10 is the worst pain and 0 is no pain.
#
# The Data Lines:
#
# Medication A: Shows a rapid and highly effective reduction in pain. It starts at a pain level of 8 and drops sharply over the first 4 hours, eventually stabilizing at a low pain level of 2 by hours 5 and 6.
#
# Medication B: Shows a steadier, but slower reduction in pain. It begins at a slightly higher pain level (9) and decreases gradually, ending at a pain level of 3 after 6 hours.

# %% [markdown]
# # Khmer Explanation
# ក្រាហ្វនេះបង្ហាញពីការប្រៀបធៀបប្រសិទ្ធភាពនៃថ្នាំពីរប្រភេទផ្សេងគ្នាក្នុងការកាត់បន្ថយការឈឺចាប់របស់អ្នកជំងឺក្នុងរយៈពេល 6 ម៉ោង
#
# អ័ក្សនៃក្រាហ្វ: អ័ក្ស X តំណាងឱ្យពេលវេលា ជាក់ស្តែងគឺចំនួនម៉ោងបន្ទាប់ពីបានលេបថ្នាំរួច។ ចំណែកឯ អ័ក្ស Y តំណាងឱ្យកម្រិតនៃភាពធ្ងន់ធ្ងរនៃការឈឺចាប់ ដែលគិតជាលេខពី 0 ដល់ 10
# បន្ទាត់ទិន្នន័យ:
#
# ថ្នាំ A: បង្ហាញពីការថយចុះនៃការឈឺចាប់យ៉ាងឆាប់រហ័ស និងមានប្រសិទ្ធភាពខ្ពស់។ វាចាប់ផ្តើមពីកម្រិតឈឺចាប់លេខ 8 ហើយធ្លាក់ចុះយ៉ាងគំហុកក្នុងរយៈពេល 4 ម៉ោងដំបូង បន្ទាប់មកនៅថេរក្នុងកម្រិតទាប (លេខ 2) នៅម៉ោងទី 5 និងទី 6
#
# ថ្នាំ B: បង្ហាញពីការថយចុះនៃការឈឺចាប់ជាលំដាប់ ប៉ុន្តែយឺតជាង។ វាចាប់ផ្តើមពីកម្រិតឈឺចាប់ខ្ពស់ជាងបន្តិច (លេខ 9) ហើយធ្លាក់ចុះបន្តិចម្តងៗ ដោយបញ្ចប់នៅកម្រិតឈឺចាប់លេខ 3 បន្ទាប់ពី 6 ម៉ោង
